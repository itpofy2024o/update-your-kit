# %%
# !source .gym-ai-venv/bin/activate

# %%
# !pip3 list
# Out:
# Package                               Version
# ------------------------------------- ----------------
# absl-py                               1.4.0
# aiohttp                               3.8.5
# aiohttp-cors                          0.7.0
# aiorwlock                             1.3.0
# aiosignal                             1.3.1
# alembic                               1.11.3
# anyio                                 3.7.1
# appdirs                               1.4.4
# argon2-cffi                           21.1.0
# arrow                                 1.2.3
# asttokens                             2.2.1
# astunparse                            1.6.3
# async-lru                             2.0.3
# async-timeout                         4.0.3
# atom-ml                               5.2.0
# attrs                                 23.1.0
# Babel                                 2.12.1
# backcall                              0.2.0
# bcc                                   0.18.0
# ...
